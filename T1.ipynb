# %% [markdown]
# <a href="https://colab.research.google.com/github/NichoLawliet/ML/blob/main/T1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
directorio="https://raw.githubusercontent.com/NichoLawliet/ML/main/"

base_data_mensual="housing_in_london_monthly_variables.csv"
base_data_anual="housing_in_london_yearly_variables.csv"
df1=pd.read_csv(directorio+base_data_mensual)
df2=pd.read_csv(directorio+base_data_anual)

data=pd.merge(df1,df2)
data.head()
# Out:
#          date            area  average_price       code  houses_sold  \
# 0  1999-12-01  city of london         169309  E09000001         97.0
# 1  2000-12-01  city of london         314772  E09000001         33.0
# 2  2001-12-01  city of london         362204  E09000001         17.0
# 3  2002-12-01  city of london         262197  E09000001         44.0
# 4  2003-12-01  city of london         305556  E09000001         38.0
#
#    no_of_crimes  borough_flag  median_salary  life_satisfaction mean_salary  \
# 0           NaN             1        33020.0                NaN       48922
# 1           NaN             1        34903.0                NaN       52203
# 2           0.0             1        39104.0                NaN       62819
# 3           0.0             1        39750.0                NaN       56450
# 4           0.0             1        41795.0                NaN       64272
#
#   recycling_pct  population_size  number_of_jobs  area_size  no_of_houses
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 903 entries, 0 to 902
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               903 non-null    object
#  1   area               903 non-null    object
#  2   average_price      903 non-null    int64
#  3   code               903 non-null    object
#  4   houses_sold        860 non-null    float64
#  5   no_of_crimes       617 non-null    float64
#  6   borough_flag       903 non-null    int64
#  7   median_salary      881 non-null    float64
#  8   life_satisfaction  320 non-null    float64
#  9   mean_salary        903 non-null    object
#  10  recycling_pct      820 non-null    object
#  11  population_size    860 non-null    float64
#  12  number_of_jobs     779 non-null    float64
#  13  area_size          666 non-null    float64
#  14  no_of_houses       666 non-null    float64
# dtypes: float64(8), int64(2), object(5)
# ...

# %%
data.describe()
# Out:
#        average_price  houses_sold  no_of_crimes  borough_flag  median_salary  \
# count        (:,.2f)      (:,.2f)       (:,.2f)       (:,.2f)        (:,.2f)
# mean         (:,.2f)      (:,.2f)       (:,.2f)       (:,.2f)        (:,.2f)
# std          (:,.2f)      (:,.2f)       (:,.2f)       (:,.2f)        (:,.2f)
# min          (:,.2f)      (:,.2f)       (:,.2f)       (:,.2f)        (:,.2f)
# 25%          (:,.2f)      (:,.2f)       (:,.2f)       (:,.2f)        (:,.2f)
# 50%          (:,.2f)      (:,.2f)       (:,.2f)       (:,.2f)        (:,.2f)
# 75%          (:,.2f)      (:,.2f)       (:,.2f)       (:,.2f)        (:,.2f)
# max          (:,.2f)      (:,.2f)       (:,.2f)       (:,.2f)        (:,.2f)
#
#        life_satisfaction  population_size  number_of_jobs  area_size  \
# count            (:,.2f)          (:,.2f)         (:,.2f)    (:,.2f)
# mean             (:,.2f)          (:,.2f)         (:,.2f)    (:,.2f)
# ...

# %%
data.hist(bins=50,figsize=(15,10))
plt.show()
